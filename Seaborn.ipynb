# %% [markdown]
# ### Visualization of Numerical columns
# 1. relplot
# 2. scatterplot
# 3. lineplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/home1/Desktop/ML_things/Data Files/1. ST Academy - Crash course and Regression files/Movie_collection_train.csv")

# %%
df.head()
# Out:
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000           20.1264               59.62               0.462
# 1       43200           20.5462               69.14               0.531
# 2       69400           20.5458               69.14               0.531
# 3       66800           20.6474               59.36               0.542
# 4       72400           21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  Time_taken  \
# ...

# %%
sns.set(style = 'darkgrid')

# %% [markdown]
# #### Relplot

# %%
sns.relplot(x='Lead_ Actor_Rating',y='Collection',data = df)

# %%
df['Genre'].value_counts()
# Out:
# Thriller    151
# Comedy      115
# Drama        81
# Action       53
# Name: Genre, dtype: int64

# %%
sns.relplot(x='Director_rating',y='Collection',hue = 'Genre',data = df)

# %%
sns.relplot(x='Director_rating',y='Collection',hue = 'Genre',data = df,size = '3D_available')

# %%
sns.relplot(x='Director_rating',y='Collection',hue = 'Genre',data = df,size = '3D_available',style = 'MPAA_film_rating')

# %%
sns.relplot(x='Lead_ Actor_Rating',y='Collection',data = df,kind = 'line',sort = True)

# %%
sns.relplot(x='Lead_ Actor_Rating',y='Collection',data = df,kind = 'line',sort = False)

# %%
sns.relplot(x = 'Director_rating', y = 'Collection', hue = 'Genre', style = 'MPAA_film_rating', kind = 'line', data = df)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = True)

# %%
from numpy.random import randn
df = pd.DataFrame(dict(time = pd.date_range('2019-06-02', periods = 500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2019-06-02  0.972419
# 1 2019-06-03  0.994252
# 2 2019-06-04  2.049616
# 3 2019-06-05  2.859438
# 4 2019-06-06  0.369578

# %%
g = sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
g.fig.autofmt_xdate()

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %% [markdown]
# #### Line plot

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# #### Scatter plot

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', size = 'size', style = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Visualization of Categorical columns
# 1. catplot
# 2. boxplot
# 3. stripplot
# 4. swarmplot

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',data = tips)

# %%
sns.catplot(x='day',y='total_bill',data = tips,jitter = False)

# %%
sns.catplot(x='day',y='total_bill',data = tips,hue = 'size',kind = 'swarm')

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order= ['Yes', 'No'])

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'sex', dodge = True)

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color',y = 'price',kind = 'boxen',data = diamonds.sort_values('color'))

# %%
sns.catplot(x = 'day', y = 'total_bill', kind = 'boxen', data = tips, dodge = True)

# %%
sns.catplot(x = 'total_bill', y = 'day', hue = 'sex', kind = 'violin', data = tips, split = False)

# %%
g = sns.catplot(x = 'day', y = 'total_bill', kind = 'violin', inner = None, data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', color = 'k', size = 3, data = tips, ax = g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x = 'deck', kind = 'count', palette = 'ch:10.000', data = titanic, hue = 'class')

# %% [markdown]
# ### checking the data how it is distrubuted

# %%
x = randn(1000)

# %%
sns.distplot(x, kde = True, hist = True, rug= False, bins= 30)
# Out:
# F:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %%
sns.jointplot(x = x, y=y, kind = 'hex')

# %%
sns.jointplot(x = x, y = y, kind = 'kde')

# %%
f, ax = plt.subplots(figsize = (6,6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
sns.kdeplot(x, y, cmap = cmap, n_levels=60, shade=True)
# Out:
# F:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g = sns.jointplot(x, y, kind = 'kde', color = 'r')
g.plot_joint(plt.scatter, c = 'w', s = 30, linewidth = 1, marker = '+')
g.ax_joint.collections[0].set_alpha(0)
# Out:
# F:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(tips)

# %% [markdown]
# ### Linear regression relationships

# %%
sns.lmplot(x = 'total_bill', y= 'tip', data = tips)

# %%
data = sns.load_dataset('anscombe')
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
f, ax = plt.subplots(figsize = (8,4))
sns.regplot(x = 'total_bill', y = 'tip', data = tips, ax = ax)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'day', col_wrap=2, height = 4)

# %% [markdown]
# ### Plotted figure aesthetics

# %%
def sinplot():
    x = np.linspace(0, 14, 100)
    for i in range(1, 5):
        plt.plot(x, np.sin(x+i*0.5)*(7-i))

# %%
sinplot()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in'})
sinplot()
sns.despine(left = True, bottom= False)

# %%
sns.set_style('darkgrid')

# %%
sns.set_context('talk', font_scale=1.5)
sinplot()

# %%
sns.palplot(sns.color_palette('hls', 8))
